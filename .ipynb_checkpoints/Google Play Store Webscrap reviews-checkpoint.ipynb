# %%
import json
import pandas as pd
from tqdm import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

from pygments import highlight
from pygments.lexers import JsonLexer
from pygments.formatters import TerminalFormatter

from google_play_scraper import Sort, reviews, app #https://github.com/JoMingyu/google-play-scraper

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)

# %%
app_packages = [
    'us.zoom.videomeetings',
    'com.shopee.sg',
    'sg.ndi.sp',
    'com.kitkats.qrscanner',
    'com.intsig.camscanner',
    'com.ss.android.ugc.trill',
    'org.telegram.messenger',
    'sg.gov.tech.bluetrace',
    'com.whatsapp',
    'com.lazada.android',
    'com.global.foodpanda.android',
    'com.instagram.android'
]

# %%
app_infos = []

for ap in tqdm(app_packages):
    info = app(ap, lang='en', country='us')
    del info['comments']
    app_infos.append(info)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:02<00:00,  4.48it/s]

# %%
def print_json(json_object):
    json_str = json.dumps(
    json_object,
    indent=2,
    sort_keys=True,
    default=str
    )
    print(highlight(json_str, JsonLexer(), TerminalFormatter()))

# %%
print_json(app_infos[2])
# Out:
# {
#   "adSupported": null,
#   "androidVersion": "6.0",
#   "androidVersionText": "6.0 and up",
#   "appId": "sg.ndi.sp",
#   "containsAds": false,
#   "contentRating": "Everyone",
#   "contentRatingDescription": null,
#   "currency": "USD",
#   "description": "Log in within seconds using your fingerprint or 6-digit passcode.\r\n\r\n<b>KEY FEATURES</b>\r\n\r\n- View your government-verified data in one place\r\n\r\nWith the new MyInfo Profile feature, customize the data you want to see. Choose from your passport expiry date, CPF account information, HDB property, and more.\r\n\r\n- Say goodbye to long passwords\r\n\r\nYou don\u2019t have to enter your SingPass ID or password anymore. With QR Login. simply scan or tap the QR code to launch the app, verify and you\u2019re in! You can also launch commonly-used digital services directly from the app with our Login Shortcut feature.\r\n\r\n- Transact securely on-the-go\r\n\r\nGoing for a holiday or staying overseas? Enjoy greater mobility when you use the new SingPass Mobile app. No more waiting for SMS OTP, or carrying a token around!\r\n\r\n<b>SET UP IN 3 EASY STEPS</b>\r\n\r\nTo set up, all you need is a smartphone, an internet connection, and a registered SingPass account.\r\n\r\n- Step 1: Install SingPass Mobile by clicking the button above.\r\n\r\n- Step 2: Complete a one-time set up.\r\n\r\n- Step 3: You\u2019re all set. Log in to government digital services using your fingerprint or 6-digit passcode \u2013 it\u2019s that simple!\r\n\r\n<b>FEEDBACK</b>\r\n\r\nWe want to hear from you! For any feedback or questions, please email us at support@singpass.gov.sg.\r\n\r\nNote: SingPass Mobile can only be installed on one device at a time.\r\n\r\nThis application is brought to you by the Government Technology Agency of Singapore.\r\n\r\n<b>APP PERMISSIONS</b>\r\n\r\nIn order to provide the service, the app requires certain permissions.\r\n\r\n[Mandatory]\r\n\u201cPhone\u201d: This permission is used to obtain your device\u2019s IMEI, among other parameters, to secure the app and generate a unique ID to tag the app to your device.\r\n\r\n[Mandatory]\r\n\u201cStorage\u201d, may also be known as \u201cPhotos, media and files\u201d: This permission allows the app to obtain additional parameters from the device storage hardware as one of the factors in deriving the unique ID for enhanced security. A file is also created on your storage to save your troubleshooting ID when logs are sent to our Helpdesk.\r\n\r\nThe following requirements are recommended for an optimised user experience:\r\n\r\n- Minimum Android version 6\r\n- At least 100MB storage space\r\n- Google Play services installed\r\n\r\n<b>COMMON ISSUES</b>\r\n\r\nIf you\u2019re encountering a \u201csettings altered\u201d prompt, it may be due to a rooted device. Certain apps that provide fake GPS or remote administration functions may also cause the prompt to be shown. While the team is continuously assessing these apps, users may choose to uninstall such apps to use SingPass Mobile.\r\n\r\nIf you\u2019re encountering a \u201crequest expired\u201d prompt, try setting your device to use \u201cAutomatic Date & Time\u201d or \u201cAutomatic Timezone\u201d. The exact name may differ according to your device, and can be found in your device settings.",
#   "descriptionHTML": "Log in within seconds using your fingerprint or 6-digit passcode.<br><br><b>KEY FEATURES</b><br><br>- View your government-verified data in one place<br><br>With the new MyInfo Profile feature, customize the data you want to see. Choose from your passport expiry date, CPF account information, HDB property, and more.<br><br>- Say goodbye to long passwords<br><br>You don\u2019t have to enter your SingPass ID or password anymore. With QR Login. simply scan or tap the QR code to launch the app, verify and you\u2019re in! You can also launch commonly-used digital services directly from the app with our Login Shortcut feature.<br><br>- Transact securely on-the-go<br><br>Going for a holiday or staying overseas? Enjoy greater mobility when you use the new SingPass Mobile app. No more waiting for SMS OTP, or carrying a token around!<br><br><b>SET UP IN 3 EASY STEPS</b><br><br>To set up, all you need is a smartphone, an internet connection, and a registered SingPass account.<br><br>- Step 1: Install SingPass Mobile by clicking the button above.<br><br>- Step 2: Complete a one-time set up.<br><br>- Step 3: You\u2019re all set. Log in to government digital services using your fingerprint or 6-digit passcode \u2013 it\u2019s that simple!<br><br><b>FEEDBACK</b><br><br>We want to hear from you! For any feedback or questions, please email us at support@singpass.gov.sg.<br><br>Note: SingPass Mobile can only be installed on one device at a time.<br><br>This application is brought to you by the Government Technology Agency of Singapore.<br><br><b>APP PERMISSIONS</b><br><br>In order to provide the service, the app requires certain permissions.<br><br>[Mandatory]<br>\u201cPhone\u201d: This permission is used to obtain your device\u2019s IMEI, among other parameters, to secure the app and generate a unique ID to tag the app to your device.<br><br>[Mandatory]<br>\u201cStorage\u201d, may also be known as \u201cPhotos, media and files\u201d: This permission allows the app to obtain additional parameters from the device storage hardware as one of the factors in deriving the unique ID for enhanced security. A file is also created on your storage to save your troubleshooting ID when logs are sent to our Helpdesk.<br><br>The following requirements are recommended for an optimised user experience:<br><br>- Minimum Android version 6<br>- At least 100MB storage space<br>- Google Play services installed<br><br><b>COMMON ISSUES</b><br><br>If you\u2019re encountering a \u201csettings altered\u201d prompt, it may be due to a rooted device. Certain apps that provide fake GPS or remote administration functions may also cause the prompt to be shown. While the team is continuously assessing these apps, users may choose to uninstall such apps to use SingPass Mobile.<br><br>If you\u2019re encountering a \u201crequest expired\u201d prompt, try setting your device to use \u201cAutomatic Date &amp; Time\u201d or \u201cAutomatic Timezone\u201d. The exact name may differ according to your device, and can be found in your device settings.",
#   "developer": "Government Technology Agency",
#   "developerAddress": null,
#   "developerEmail": "support@singpass.gov.sg",
#   "developerId": "Government+Technology+Agency",
#   "developerInternalID": "7758890186913038523",
#   "developerWebsite": "https://singpassmobile.sg",
#   "free": true,
#   "genre": "Productivity",
#   "genreId": "PRODUCTIVITY",
#   "headerImage": "https://lh3.googleusercontent.com/nvHKuOlarLMjHLMNax-e__SL570QgFqbaNbOmfLZ0RauZX9Y0QLu-lIVZL7XV5pxkNEU",
#   "histogram": [
#     1766,
#     491,
#     742,
#     2177,
#     10689
#   ],
#   "icon": "https://lh3.googleusercontent.com/LtK1q01LXW5mqFdgf7zDudggLlyiBBLGZFXYygo2iMD2ldpee-SrWUw2AnDl8kFAwxMu",
#   "inAppProductPrice": null,
#   "installs": "1,000,000+",
#   "minInstalls": 1000000,
#   "offersIAP": false,
#   "originalPrice": null,
#   "price": 0,
#   "privacyPolicy": "https://www.singpass.gov.sg/singpass/common/privacystatement",
#   "ratings": 15865,
#   "recentChanges": "v6.0.1/2:\r\n- Bug fixes for the SingPass Face Verification onboarding flow\r\n- Bug fix for Exynos devices when renewing their identity certificates\r\n- Bug fix for QR scan\r\n\r\nNEW in v6.0:\r\n- Overseas or don't have 2FA handy? Use SingPass Face Verification to set up the app instead\r\n- Your scan is verified against the Government biometric database to confirm your identity (nothing is stored locally)\r\n- Long-time users of the app may see a banner prompt to renew their identity certificates on the Home page",
#   "recentChangesHTML": "v6.0.1/2:<br>- Bug fixes for the SingPass Face Verification onboarding flow<br>- Bug fix for Exynos devices when renewing their identity certificates<br>- Bug fix for QR scan<br><br>NEW in v6.0:<br>- Overseas or don&#39;t have 2FA handy? Use SingPass Face Verification to set up the app instead<br>- Your scan is verified against the Government biometric database to confirm your identity (nothing is stored locally)<br>- Long-time users of the app may see a banner prompt to renew their identity certificates on the Home page",
#   "released": "Oct 19, 2018",
#   "reviews": 3931,
#   "sale": false,
#   "saleText": null,
#   "saleTime": null,
#   "score": 4.2308664,
#   "screenshots": [
#     "https://lh3.googleusercontent.com/jsnViylAla3z8tPtSgiOMMMu9ssrPq8pb4SgeyEqO_3CSf9Njabmou-NnjbVtmAcL_Ip",
#     "https://lh3.googleusercontent.com/ybqY_GxxjryKzHp8OY1M0xXTlEVcPdhz-oDiCxD7JFvCgCuYu4bbv4Z8-ZsNSYGjiHo",
#     "https://lh3.googleusercontent.com/lJbTjwHTZiVBo34MXNzS4rkIAzA1WFlsWdirgbpllSHIjc-3J_0HnNkPGCzkW_RqkvI",
#     "https://lh3.googleusercontent.com/1FxtdMiPMPXLSNR1M6tkRUYbWHumcOPcMfpbgbHzELr0Armvx46ZbPlJ82_-hwsS_w",
#     "https://lh3.googleusercontent.com/RMDYyPEDizSywVmYvDEq4xFeN5Hjl0-Z6TC3qckSOr5ylY9Qq7iW1jvZoGmj2UpRcg",
#     "https://lh3.googleusercontent.com/bHesyoTj_xpKSnwwdvcFOnXfI3GEgV8EDpmZHtCDqWCOvj7Yo-fiIwUvwb-AkOCSFnU5",
#     "https://lh3.googleusercontent.com/dBiuMR5dG4wsRkC7HGT4k5O5BLjjbeGhyxGMGxfhyH3pMlkLxJNHmfrNbeHlgLaLQzI",
#     "https://lh3.googleusercontent.com/bQLp4xjglua4MHmZbXWNIJwXioEcqlzgVGNZxxqMvjBtt8v7DsqG3nOxxM__lYusz2w"
#   ],
#   "size": "35M",
#   "summary": "Your trusted digital identity",
#   "summaryHTML": "Your trusted digital identity",
#   "title": "SingPass Mobile",
#   "updated": 1598091431,
#   "url": "https://play.google.com/store/apps/details?id=sg.ndi.sp&hl=en&gl=us",
#   "version": "6.0.2",
#   "video": "https://www.youtube.com/embed/dDrqT64ydd0?ps=play&vq=large&rel=0&autohide=1&showinfo=0",
#   "videoImage": "https://i.ytimg.com/vi/dDrqT64ydd0/hqdefault.jpg"
# }

# %%
def format_title(title):
    sep_index = title.find(':') if title.find(':') != -1 else title.find('-')
    if sep_index != -1:
        title = title[:sep_index]
    return title[:10]

fig, axs = plt.subplots(2, len(app_infos) // 2, figsize=(14, 5))

for i, ax in enumerate(axs.flat):
    ai = app_infos[i]
    img = plt.imread(ai['icon'])
    ax.imshow(img)
    ax.set_title(format_title(ai['title']))
    ax.axis('off')

# %%
app_infos_df = pd.DataFrame(app_infos)
app_infos_df.to_csv('apps.csv', index=None, header=True)

# %%
app_reviews = []

for ap in tqdm(app_packages):
    for sort_order in [Sort.MOST_RELEVANT, Sort.NEWEST]:
        rvs, _ = reviews(ap,lang='en',
                         country='us',
                         sort=sort_order,
                         count= 200
                        )
    for r in rvs:
        r['sortOrder'] = 'most_relevant' if sort_order == Sort.MOST_RELEVANT else 'newest'
        r['appId'] = ap
    app_reviews.extend(rvs)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:07<00:00,  1.50it/s]

# %%
len(app_reviews)
# Out:
# 2400

# %%
app_reviews_df = pd.DataFrame(app_reviews)
app_reviews_df.to_csv('reviews.csv', index=None, header=True)

# %%
app_reviews[0]
# Out:
# {'reviewId': 'gp:AOqpTOErzDijmVIUHSZsIgOGg3LXbjcPj-st5qooim-r5rJT0Vu43jjsqA868zi2hT2dmFHkB-7eGkz7i2_Kuw',
#  'userName': 'Siva Parvathi devi',
#  'userImage': 'https://lh3.googleusercontent.com/-vaZKw5WvjJE/AAAAAAAAAAI/AAAAAAAAAAA/AMZuucnYfuzTWsVgzyFEjoHlXSczcqaMlQ/photo.jpg',
#  'content': "It's a wrost one showing error and I am getting missed my meetings🤯🤯😠😠😠😡😡😡👿👿😤😤😤😤",
#  'score': 1,
#  'thumbsUpCount': 0,
#  'reviewCreatedVersion': None,
#  'at': datetime.datetime(2020, 9, 3, 22, 42, 25),
#  'replyContent': None,
#  'repliedAt': None,
#  'sortOrder': 'newest',
#  'appId': 'us.zoom.videomeetings'}

# %%
app_reviews_df['score'].value_counts()
# Out:
# 5    1498
# 1     468
# 4     212
# 3     137
# 2      85
# Name: score, dtype: int64
