# %%
from app_store_scraper import AppStore
import pandas as pd

# %%
shoppee = AppStore(country = 'sg', app_name = 'shoppee')
shoppee.review(how_many = 20)
# Out:
# 2020-09-14 21:25:04,753 [INFO] Base - Searching for app id
# 2020-09-14 21:25:06,091 [INFO] Base - Initialised: AppStore('sg', 'shoppee', 959840394)
# 2020-09-14 21:25:06,096 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/shoppee/id959840394
# 2020-09-14 21:25:06,390 [INFO] Base - [id:959840394] Fetched 20 reviews (20 fetched in total)

# %%
lazada = AppStore(country = 'sg', app_name = 'lazada')
lazada.review(how_many = 20)
# Out:
# 2020-09-14 21:25:06,403 [INFO] Base - Searching for app id
# 2020-09-14 21:25:08,618 [INFO] Base - Initialised: AppStore('sg', 'lazada', 1315605408)
# 2020-09-14 21:25:08,622 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/lazada/id1315605408
# 2020-09-14 21:25:08,911 [INFO] Base - [id:1315605408] Fetched 20 reviews (20 fetched in total)

# %%
df_shoppee = pd.DataFrame(shoppee.reviews)
df_lazada = pd.DataFrame(lazada.reviews)
df_shoppee['app_Id'] = 'shoppee'
df_lazada['app_Id'] = 'lazada'
df = df_shoppee.append(df_lazada, ignore_index = True)
df.head()
# Out:
#                                              title  \
# 0   Good in price and customers’ interest platform
# 1                                   Bad experience
# 2                                    Waste of time
# 3  Shoppee is not one of the best shopping app...!
# 4                                     Disappointed
#
#                                    developerResponse  \
# 0  {'id': 17097958, 'body': 'Thank you for giving...
# 1  {'id': 12456571, 'body': 'Hey,
#
# Thank you for ...
# 2  {'id': 17059815, 'body': 'Thank you for bringi...
# 3  {'id': 11615436, 'body': 'Hey, :D
#
# Thank you f...
# 4  {'id': 14589371, 'body': 'Thank you for bringi...
#
#                                               review  isEdited  \
# 0  Shopee is a platform that protecting customers...     False
# 1  I have been used this app for years. However t...     False
# 2  I regretted choosing shopee. Reason being: Pur...     False
# 3  Who says shopee is one of the best shopping ap...      True
# 4  Initially when Shopee started, transactions ar...     False
#
#                  date          userName  rating   app_Id
# 0 2020-08-05 05:32:41   Little tortoise       5  shoppee
# 1 2019-12-17 15:59:30            Tujimu       1  shoppee
# 2 2020-08-03 09:08:40             Xed82       1  shoppee
# 3 2019-12-09 08:02:35  Cartoonfreak1980       5  shoppee
# 4 2020-04-10 04:39:06       Raymond Koh       1  shoppee

# %%
app_packages = ['shoppee', 
                'lazada', 
                'carousell',
               'ebay',
               'amazon',
               'asos',
               'wish',
               'aliexpress']

app_id = [959840394, 
          785385147, 
          548607187, 
          282614216, 
          297606951, 
          457876088, 
          530621395, 
          436672029]

for i in range(len(app_packages)):
    name = app_packages[i]
    app = app_packages
    app[i] = AppStore(country = 'sg', app_name = name, app_id = app_id[i], log_interval = 120)
    app[i].review(how_many = 10000)
    app_packages[i] =  pd.DataFrame(app_packages[i].reviews)
    app_packages[i]['AppId'] = name
    
df = app_packages[0]
for j in range(1, len(app_packages)):
        df = df.append(app_packages[j])

df.reset_index(inplace = True)
# Out:
# 2020-09-14 21:25:09,067 [INFO] Base - Initialised: AppStore('sg', 'shoppee', 959840394)
# 2020-09-14 21:25:09,068 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/shoppee/id959840394
# 2020-09-14 21:25:52,127 [INFO] Base - [id:959840394] Fetched 2949 reviews (2949 fetched in total)
# 2020-09-14 21:25:52,208 [INFO] Base - Initialised: AppStore('sg', 'lazada', 785385147)
# 2020-09-14 21:25:52,209 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/lazada/id785385147
# 2020-09-14 21:26:19,674 [INFO] Base - [id:785385147] Fetched 1893 reviews (1893 fetched in total)
# 2020-09-14 21:26:20,748 [INFO] Base - Initialised: AppStore('sg', 'carousell', 548607187)
# 2020-09-14 21:26:20,750 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/carousell/id548607187
# 2020-09-14 21:28:11,941 [INFO] Base - [id:548607187] Fetched 6810 reviews (6810 fetched in total)
# 2020-09-14 21:28:13,672 [INFO] Base - Initialised: AppStore('sg', 'ebay', 282614216)
# 2020-09-14 21:28:13,677 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/ebay/id282614216
# 2020-09-14 21:28:24,704 [INFO] Base - [id:282614216] Fetched 663 reviews (663 fetched in total)
# 2020-09-14 21:28:25,718 [INFO] Base - Initialised: AppStore('sg', 'amazon', 297606951)
# 2020-09-14 21:28:25,721 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/amazon/id297606951
# 2020-09-14 21:28:27,705 [INFO] Base - [id:297606951] Fetched 118 reviews (118 fetched in total)
# 2020-09-14 21:28:28,970 [INFO] Base - Initialised: AppStore('sg', 'asos', 457876088)
# 2020-09-14 21:28:28,973 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/asos/id457876088
# 2020-09-14 21:28:37,609 [INFO] Base - [id:457876088] Fetched 572 reviews (572 fetched in total)
# 2020-09-14 21:28:38,607 [INFO] Base - Initialised: AppStore('sg', 'wish', 530621395)
# 2020-09-14 21:28:38,613 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/wish/id530621395
# 2020-09-14 21:28:44,269 [INFO] Base - [id:530621395] Fetched 373 reviews (373 fetched in total)
# 2020-09-14 21:28:45,282 [INFO] Base - Initialised: AppStore('sg', 'aliexpress', 436672029)
# 2020-09-14 21:28:45,286 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/sg/app/aliexpress/id436672029
# 2020-09-14 21:28:55,313 [ERROR] Base - Something went wrong: 'data'
# 2020-09-14 21:28:55,314 [INFO] Base - [id:436672029] Fetched 660 reviews (660 fetched in total)

# %%
df
# Out:
#        index                                            title  \
# 0          0   Good in price and customers’ interest platform
# 1          1                                   Bad experience
# 2          2                                    Waste of time
# 3          3  Shoppee is not one of the best shopping app...!
# 4          4                                     Disappointed
# ...      ...                                              ...
# 14033    655                     Good apps to shop from china
# 14034    656                                    Excellent App
# 14035    657                              Loving it so far!!!
# 14036    658                                         Crashing
# 14037    659                             Rate AliExpress Apps
#
#                                        developerResponse  \
# 0      {'id': 17097958, 'body': 'Thank you for giving...
# 1      {'id': 12456571, 'body': 'Hey,
#
# Thank you for ...
# 2      {'id': 17059815, 'body': 'Thank you for bringi...
# 3      {'id': 11615436, 'body': 'Hey, :D
#
# Thank you f...
# 4      {'id': 14589371, 'body': 'Thank you for bringi...
# ...                                                  ...
# 14033                                                NaN
# 14034                                                NaN
# 14035                                                NaN
# 14036                                                NaN
# 14037                                                NaN
#
#                                                   review  isEdited  \
# 0      Shopee is a platform that protecting customers...     False
# 1      I have been used this app for years. However t...     False
# 2      I regretted choosing shopee. Reason being: Pur...     False
# 3      Who says shopee is one of the best shopping ap...      True
# 4      Initially when Shopee started, transactions ar...     False
# ...                                                  ...       ...
# 14033            Used this app to buy things from china.     False
# 14034  All the products displayed in app are quality ...     False
# 14035  So far hadn't had issue with Aliexpress\nI lov...     False
# 14036  Current update has been crashing? Has been ove...     False
# 14037  Easy to move from pages to pages.\nVery helpfu...     False
#
#                      date          userName  rating       AppId
# 0     2020-08-05 05:32:41   Little tortoise       5     shoppee
# 1     2019-12-17 15:59:30            Tujimu       1     shoppee
# 2     2020-08-03 09:08:40             Xed82       1     shoppee
# 3     2019-12-09 08:02:35  Cartoonfreak1980       5     shoppee
# 4     2020-04-10 04:39:06       Raymond Koh       1     shoppee
# ...                   ...               ...     ...         ...
# 14033 2019-05-31 11:58:39            Adefer       5  aliexpress
# 14034 2019-04-06 10:20:16         hellodont       5  aliexpress
# 14035 2019-02-21 07:49:49             SSTSY       5  aliexpress
# 14036 2019-03-25 13:57:45         Kikoman69       3  aliexpress
# 14037 2019-03-06 04:04:43  Just Hamba Allah       4  aliexpress
#
# [14038 rows x 9 columns]

# %%
df.shape
# Out:
# (14038, 9)

# %%
df.to_csv('apple_apps_reviews.csv', index=None, header=True)
